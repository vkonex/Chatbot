# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from random import choice
import json
import glob
import os
import pickle
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
#from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
import random
from collections import ChainMap

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']

# %%
import pandas as pd
base_dir = r'C:\Users\hani\Desktop\chat\dlchatbotmain\files'
data_list =[] 
for file in os.listdir(base_dir):
    #print(file)
    if 'json' in file:
        json_path = os.path.join(base_dir, file)
        #print(json_path)
        json_data = json.load(open(json_path, encoding='utf-8'))
        data_list.extend(json_data)
data_list
# Out:
# [{'tag': 'class_1_1',
#   'patterns': ['How many pigs were ?', 'How many pigs were there?'],
#   'responses': ['There were three pigs.']},
#  {'tag': 'class_1_2',
#   'patterns': ['What did the big wolf say to the pigs?',
#    'What did the big wolf say to the '],
#   'responses': ['The big wolf said to the pigs that; \n he would will huff and puff and; \n blow their houses down']},
#  {'tag': 'class_1_3',
#   'patterns': ['Was the wolf good or ?', 'Was the wolf good or bad?'],
#   'responses': ['The wolf was bad.']},
#  {'tag': 'class_1_4',
#   'patterns': ['What is your house made of?', 'What is your house ?'],
#   'responses': ['My house is made of; \n bricks and cement.']},
#  {'tag': 'class_1_5',
#   'patterns': ['Who is good?', 'is that good'],
#   'responses': ['The pig is good']},
#  {'tag': 'class_1_6',
#   'patterns': ['Who is bad?', 'is bad'],
#   'responses': ['The wolf is bad.']},
#  {'tag': 'class_1_7',
#   'patterns': ['Imagine you are at home when the wolf huffs and puffs.',
#    'Imagine you are at home when the wolf huffs'],
#   'responses': ['Activity to be;\n done by yourself.']},
#  {'tag': 'class_1_8',
#   'patterns': ['Act out the story of the wolf and three pigs.',
#    'Act out the story of the wolf '],
#   'responses': ['Activity to be; \n done by yourself.']},
#  {'tag': 'class_1_9',
#   'patterns': ['Do you like to have a bath? Say why.',
#    'Do you like to have a bath? '],
#   'responses': ['Yes, I like to have a bath every;\n day to keep myself healthy, neat and tidy.']},
#  {'tag': 'class_2_0',
#   'patterns': ['Can you bathe yourself?', 'Can you bathe '],
#   'responses': ['Yes, I can bathe myself.']},
#  {'tag': 'class_2_1',
#   'patterns': ['How do you dry yourself?', 'How do you dry'],
#   'responses': ['I dry myself after a bath; \n by using a fresh towel.']},
#  {'tag': 'class_2_2',
#   'patterns': ['Have you seen an animal drying itself?',
#    'Have you seen an animal drying ?'],
#   'responses': ['Yes, I have seen my pet dog drying; \n itself by shaking off the excess water; \n from its body whenever I bathe it.']},
#  {'tag': 'class_2_3',
#   'patterns': ['Name the three friends.', 'Name the three '],
#   'responses': ['The three friends are the Bubble,; \n the Straw and the Shoe.']},
#  {'tag': 'class_2_4',
#   'patterns': ['Where did they go one day?', 'Where did they go ?'],
#   'responses': ['All the three friends went; \n to a forest one day.']},
#  {'tag': 'class_2_5',
#   'patterns': ['What did they want to do?', 'What did they want ?'],
#   'responses': ['They came to a river.; \n They wanted to cross it, but; \n did not know how to do it.']},
#  {'tag': 'class_2_6',
#   'patterns': ['How do you make bubbles?', 'How you make bubbles?'],
#   'responses': ['We can make bubbles by; \n taking some liquid soap in a container and mix it in water.; \n We can create a lather from; \n the mixture and use a straw to blow the; \n bubbles in the air.']},
#  {'tag': 'class_2_7',
#   'patterns': ['What do you wear on your feet?', 'do you wear on your feet?'],
#   'responses': ['I wear shoes, sandals, ; \n socks, etc. on my feet.']},
#  {'tag': 'class_2_8',
#   'patterns': ['How would you cross a river?', 'would you cross a river?'],
#   'responses': ['I would cross a river in a boat.']},
#  {'tag': 'class_2_9',
#   'patterns': ['How many kinds of creatures are there in the poem?',
#    'many kinds of creatures are there in the poem?'],
#   'responses': ['There are fifteen creatures; \n mentioned in the poem.']},
#  {'tag': 'class_3_0',
#   'patterns': ['are the seals happy?', 'the seals happy?'],
#   'responses': ['No, the seals are sad.']},
#  {'tag': 'class_3_1',
#   'patterns': ['Where do the fish live?', 'do the fish live?'],
#   'responses': ['The fish live in the water; \n (river, sea or ocean).']},
#  {'tag': 'class_3_2',
#   'patterns': ['What are the other things found in water?',
#    'the other things found in water?'],
#   'responses': ['The other things found in; \n water are other sea creatures, plants, oysters,; \n shells, herbs, etc.']},
#  {'tag': 'class_3_3',
#   'patterns': ['There are many creatures in the poem. Which ones have you seen?',
#    'many creatures in the poem. Which ones have you seen?'],
#   'responses': ['I have seen kitten, cats,; \n butterflies, rats, fishes, lizards,; \n bees, elephants, donkeys, etc']},
#  {'tag': 'class_3_4',
#   'patterns': ['Name the chicks in the story.', 'the chicks in the story.'],
#   'responses': ['Lalu and Peelu are the names; \n of the chicks in the story.']},
#  {'tag': 'class_3_5',
#   'patterns': ['Who liked yellow things?', 'liked yellow things?'],
#   'responses': ['Peelu liked yellow things.']},
#  {'tag': 'class_3_6',
#   'patterns': ['What did Lalu eat one day?', 'did Lalu eat one day?'],
#   'responses': ['Lalu ate a red chilli ; \n from a plant one day.']},
#  {'tag': 'class_3_7',
#   'patterns': ['What did the child see?', 'did the child see?'],
#   'responses': ['The child saw a little bird.']},
#  {'tag': 'class_3_8',
#   'patterns': ['What was the little bird doing?', 'the little bird doing?'],
#   'responses': ['The little bird sat upon a window.']},
#  {'tag': 'class_3_9',
#   'patterns': ['Do you see any birds around your school or your house?',
#    'see any birds around your school or your house?'],
#   'responses': ['Yes, I often see birds around; \n my school or my house']},
#  {'tag': 'class_4_0',
#   'patterns': ['Have you tried talking to them?',
#    'you tried talking to them?'],
#   'responses': ['Yes, I’ve tried talking to birds ; \n whenever they come and sit on my window']},
#  {'tag': 'class_4_1',
#   'patterns': ['What did Mittu see on the tree?',
#    'did Mittu see on the tree?'],
#   'responses': ['Mittu saw a big yellow; \n  mango on the tree.']},
#  {'tag': 'class_4_2',
#   'patterns': ['What did the big black crow say?',
#    'did the big black crow say?'],
#   'responses': ['The big black crow; \n told Mittu to go away.']},
#  {'tag': 'class_4_3',
#   'patterns': ['What did Mittu see under the tree?',
#    'did Mittu see under the tree?'],
#   'responses': ['Mittu saw a red balloon under the tree.']},
#  {'tag': 'class_4_4',
#   'patterns': ['Do you like eating mangoes?', 'you like eating mangoes?'],
#   'responses': ['Yes, I like eating ripe mangoes.']},
#  {'tag': 'class_4_5',
#   'patterns': ['Do you like green mangoes? Why?',
#    'you like green mangoes? Why?'],
#   'responses': ['Yes, I like green mangoes as they taste sour and; \n have a unique flavour. My grandmother prepares; \n pickles with them.']},
#  {'tag': 'class_4_6',
#   'patterns': ['Do you like yellow mangoes? Why?',
#    'you like yellow mangoes? Why?'],
#   'responses': ['Yes, I like yellow mangoes as ; \n they have a sweet flavour.']},
#  {'tag': 'class_4_7',
#   'patterns': ['How did the merry-go-round go?', 'did the merry-go-round go?'],
#   'responses': ['The merry-go-round went round and round']},
#  {'tag': 'class_4_8',
#   'patterns': ['How did the big brown horse go?',
#    'did the big brown horse go?'],
#   'responses': ['The big brown horse went up and down.']},
#  {'tag': 'class_4_9',
#   'patterns': ['Have you seen a merry-go-round?',
#    'you seen a merry-go-round?'],
#   'responses': ['Yes, I have seen a merry-go-round.']},
#  {'tag': 'class_5_0',
#   'patterns': ['Where have you seen it?', 'have you seen it?'],
#   'responses': ['I have seen a merry-go-round; \n in a fair and a park.']},
#  {'tag': 'class_5_1',
#   'patterns': ['Would you like to go to a fair?', 'you like to go to a fair?'],
#   'responses': ['Yes, I like to visit; \n a fair often.']},
#  {'tag': 'class_5_2',
#   'patterns': ['What did Grandmother and Mohini draw first?',
#    'did Grandmother and Mohini draw first?'],
#   'responses': ['Grandmother and Mohini; \n drew a circle at first.']},
#  {'tag': 'class_5_3',
#   'patterns': ['What were the colours of the balloons that Mohini drew?',
#    'were the colours of the balloons that Mohini drew?'],
#   'responses': ['Mohini drew balloons of different; \n colours such as red, blue,; \n green and yellow.']},
#  {'tag': 'class_5_4',
#   'patterns': ['Where is the apple?', 'is the apple?'],
#   'responses': ['The apple is on the tree.']},
#  {'tag': 'class_5_5',
#   'patterns': ['Where is the boy?', 'is the boy?'],
#   'responses': ['The boy is under the tree.']},
#  {'tag': 'class_5_6',
#   'patterns': ['How can the boy get the apple?', 'the boy get the apple?'],
#   'responses': ['The boy can get the apple by ; \n climbing the tree and plucking it from the tree.']},
#  {'tag': 'class_5_7',
#   'patterns': ['Do you like apples?', 'you like apples?'],
#   'responses': ['Yes, I like apples.']},
#  {'tag': 'class_5_8',
#   'patterns': ['Have you ever climbed a fruit tree?',
#    'you ever climbed a fruit tree?'],
#   'responses': ['No, I have never climbed a fruit tree']},
#  {'tag': 'class_5_9',
#   'patterns': ['Describe the picture using all the words given above.',
#    'the picture using all the words given above.'],
#   'responses': ['The tree is full of lush green leaves and; \n numerous branches.There are two birds in the picture.; \n There is also a small nest with two eggs in it.; \n A swing is tied to one of the branches.']},
#  {'tag': 'class_6_0',
#   'patterns': ['Should trees be cut?', 'the trees be cut?'],
#   'responses': ['No, Trees should not be cut.']},
#  {'tag': 'class_6_1',
#   'patterns': ['Name some trees which you have seen',
#    'some trees which you have seen'],
#   'responses': ['I have seen neem tree, mango tree, guava tree,; \n pomegranate tree, ashok tree, etc.']},
#  {'tag': 'class_6_2',
#   'patterns': ['What does the child wish to be?',
#    'does the child wish to be?'],
#   'responses': ['The child wishes to be a kite.']},
#  {'tag': 'class_6_3',
#   'patterns': ['What does the child wish to do with the breeze?',
#    'does the child wish to do with the breeze?'],
#   'responses': ['The child wishes that to ride upon the breeze ; \n and go wherever he got a chance to.']},
#  {'tag': 'class_6_4',
#   'patterns': ['What would you like to be?', 'would you like to be?'],
#   'responses': ['I would like to be a bird ; \n  and fly high in the sky.']},
#  {'tag': 'class_6_5',
#   'patterns': ['Imagine you are a bird in the sky. Describe what will you feel when you see a kite flying near you.',
#    'you are a bird in the sky. Describe what will you feel when you see a kite flying near you.'],
#   'responses': ['I will look at it and then fly a little ; \n farther so that it doesn’t harm me.']},
#  {'tag': 'class_6_6',
#   'patterns': ['What are the different things that fly in the sky?',
#    'are the different things that fly in the sky?'],
#   'responses': ['Things that fly in the sky are birds, ; \n kites, aeroplanes, helicopters, etc.']},
#  {'tag': 'class_6_7',
#   'patterns': ['If you had wings, where would you fly?',
#    'you had wings, where would you fly?'],
#   'responses': ['I would fly over mountains, rivers, etc.']},
#  {'tag': 'class_6_8',
#   'patterns': ['Who made Sundari?', 'made Sundari?'],
#   'responses': ['Bobby made Sundari.']},
#  {'tag': 'class_6_9',
#   'patterns': ['Why did Bobby call his kite ‘Sundari’?',
#    'did Bobby call his kite ‘Sundari’?'],
#   'responses': ['Bobby called his kite ‘Sundari’; \n  because it was beautiful.']},
#  {'tag': 'class_7_0',
#   'patterns': ['Did Sundari fly very high at first?',
#    'Sundari fly very high at first?'],
#   'responses': ['No, Sundari did not fly very high at first.']},
#  {'tag': 'class_7_1',
#   'patterns': ['What made Sundari really happy?',
#    'made Sundari really happy?'],
#   'responses': ['Sundari became really happy when ; \n Bobby let her go and fly high in the sky.']},
#  {'tag': 'class_7_2',
#   'patterns': ['Do you like to fly kites?', 'you like to fly kites?'],
#   'responses': ['Yes, I like to fly kites.']},
#  {'tag': 'class_7_3',
#   'patterns': ['Who helps you to fly kites', 'helps you to fly kites'],
#   'responses': ['My brother helps me to fly kites']},
#  {'tag': 'class_7_4',
#   'patterns': ['Name the objects in your own language.',
#    'the objects in your own language.'],
#   'responses': ['The student has to do as directed.']},
#  {'tag': 'class_7_5',
#   'patterns': ['Now say the story in English using the words rain, wind, crow, nest, is, has, blows, flies.',
#    'the story in English using the words rain, wind, crow, nest, is, has, blows, flies.'],
#   'responses': ['The student has to do as directed.']},
#  {'tag': 'class_7_6',
#   'patterns': ['How does a turtle walk?', 'does a turtle walk?'],
#   'responses': ['The turtle walks very slowly.']},
#  {'tag': 'class_7_7',
#   'patterns': ['What does the turtle carry on its back?',
#    'does the turtle carry on its back?'],
#   'responses': ['The turtle carries its home on its back.']},
#  {'tag': 'class_7_8',
#   'patterns': ['Where does the turtle go when it is tired?',
#    'does the turtle go when it is tired?'],
#   'responses': ['The turtle goes back to its shell when it is tired.']},
#  {'tag': 'class_7_9',
#   'patterns': ['What is the turtle’s house called?',
#    'is the turtle’s house called?'],
#   'responses': ['The turtle’s house is called a shell.']},
#  {'tag': 'class_8_0',
#   'patterns': ['What other reasons can you give for a turtle going into its house?',
#    'can you give for a turtle going into its house?'],
#   'responses': ['There can be multiple reasons for a turtle ; \n going into its house- to save itself from strong winds or storms, ; \n to hide from enemies or other dangers, etc.']},
#  {'tag': 'class_8_1',
#   'patterns': ['Imagine you are a turtle. Crawl like a turtle.',
#    'you are a turtle. Crawl like a turtle.'],
#   'responses': ['The student has to do as directed in the question.']},
#  {'tag': 'class_8_2',
#   'patterns': ['Now you are tired so get into your shell and go to sleep.',
#    'you are tired so get into your shell and go to sleep.'],
#   'responses': ['The student has to do as directed in the question.']},
#  {'tag': 'class_8_3',
#   'patterns': ['Wake up and start to crawl again.',
#    'when Wake up and start to crawl again.'],
#   'responses': ['The student has to do as directed in the question.']},
#  {'tag': 'class_8_4',
#   'patterns': ['Now hide in your shell because some naughty children are near you',
#    'your shell because some naughty children are near you'],
#   'responses': ['The student has to do as directed in the question.']},
#  {'tag': 'class_8_5',
#   'patterns': ['What was the tiger doing when the mosquito came buzzing by?',
#    'the tiger doing when the mosquito came buzzing by?'],
#   'responses': ['The tiger was dozing under a tree when the mosquito came buzzing by.']},
#  {'tag': 'class_8_6',
#   'patterns': ['Why did the tiger’s cheek start to bleed?',
#    'the tiger’s cheek start to bleed?'],
#   'responses': ['The tiger’s cheek started to bleed because ; \n while trying to hit the mosquito,; \n the tiger hit himself with his paw.']},
#  {'tag': 'class_8_7',
#   'patterns': ['Why did the tiger walk away?', 'the tiger walk away?'],
#   'responses': ['The tiger walked away because he was helpless ; \n and could not make the mosquito fly away from him.']},
#  {'tag': 'class_8_8',
#   'patterns': ['Why did the mosquito say, “I am not afraid of you!”?'],
#   'responses': ['The mosquito said so because the tiger was ; \n behaving as if everyone should be afraid of him.']},
#  {'tag': 'class_1_poems',
#   'patterns': ['A Happy Child'],
#   'responses': ['My house is red - a little house;\nA happy child am I.\nI laugh and play the whole day long,\nI hardly ever cry.\nI have a tree, a green, green tree,\nTo shade me from the sun;\nAnd under it I often sit,\nWhen all my play is done.']},
#  {'tag': 'class_1_poems1',
#   'patterns': ['After a Bath',
#    'After a Bath Poem',
#    'what is After a Bath poem',
#    'Hey teach me After a Bath poem',
#    'teach me After a Bath poem'],
#   'responses': ['After my bath\nI try, try, try\nto wipe myself\ntill I’m dry, dry, dry.\nHands to wipe\nand fingers and toes\nand two wet legs\nand a shiny nose.\nJust think how much\nless time I’d take\nif I were a dog\nand could shake, shake, shake.\n']},
#  {'tag': 'class_1_poems2',
#   'patterns': ['One little kitten',
#    'One little kitten Poem',
#    'One little kitten Rythm'],
#   'responses': ['Two big cats\nThree baby butterflies\nFour big rats\nFive fat fishes\nSix sad seals\nSeven silly seagulls\nEight happy eels;\nNine nervous lizards\nTen brave bees\nEleven smelly elephants\nTwelve fat fleas\nThirteen alligators\nFourteen whales\nFifteen donkeys\nWith fifteen tails.']},
#  {'tag': 'class_1_poems3',
#   'patterns': ['Once I saw a Little Bird',
#    'Once I saw a Little Bird Poem',
#    'Once I saw a Little Bird Rythm'],
#   'responses': ['Once I saw a little bird\nCome hop, hop, hop,\nI cried, “Little bird,\nWill you stop, stop, stop?”\nI was going to the window\nTo say, “How do you do?”\nBut he shook his little tail\nAnd away he flew.']},
#  {'tag': 'class_1_poems4',
#   'patterns': ['Merry Go Round',
#    'Merry Go Round Poem',
#    'Merry Go Round Rythm'],
#   'responses': ['I climbed up on the merry-go-round,\nAnd it went round and round.\nI climbed up on a big brown horse,\nAnd it went up and down.Around and round\nAnd up and down,\nAround and round\nAnd up and down.\nI sat high up\nOn a big brown horse\nAnd rode around\nOn the merry-go-round\nAnd rode around\nOn the merry-go-round\nI rode around\nOn the merry-go-round\nAround\nAnd round\nAnd']},
#  {'tag': 'class_1_poems5',
#   'patterns': ['If I Were an Apple',
#    'If I Were an Apple Poem',
#    'If I Were an Apple Rythm'],
#   'responses': ['If I were an apple\nAnd grew on a tree,\nI think I’d drop down\nOn a nice boy like me.\nI wouldn’t stay there\nGiving nobody joy,\nI’d fall down at once\nAnd say, “Eat me, my boy!']},
#  {'tag': 'greeting',
#   'patterns': ['Hi there',
#    'How are you',
#    'Is anyone there?',
#    'Hey',
#    'Hola',
#    'Hello',
#    'Good day',
#    'Hey',
#    'Ekse',
#    'Hi'],
#   'responses': ['Hi stranger',
#    'Yebo yes, how can I help',
#    'Ey watsupp',
#    'Ekse Hoezit',
#    'Hola',
#    'Hey dude',
#    'You again']},
#  {'tag': 'goodbye',
#   'patterns': ['Bye', 'See you later', 'Goodbye', 'Ok bye', 'Bye Bye'],
#   'responses': ['See you!',
#    'Have a nice day',
#    'Sure Bye',
#    'Later dude',
#    'Sayoonara',
#    'Peace out',
#    'Sure dude',
#    'Ciao']},
#  {'tag': 'thanks',
#   'patterns': ['Thanks',
#    'Thank you',
#    "That's helpful",
#    'Awesome, thanks',
#    'Thanks for helping me'],
#   'responses': ['Happy to help!',
#    'Any time!',
#    'My pleasure',
#    'You are welcome',
#    'Sure dude']},
#  {'tag': 'noanswer',
#   'patterns': [],
#   'responses': ["Sorry, can't understand you",
#    'Please give me more info',
#    'Not sure I understand',
#    'I am still here dude']},
#  {'tag': 'name',
#   'patterns': ['What is your name',
#    'Whats your name',
#    'Tell me your name',
#    'Who are you',
#    'Ungubani',
#    'Tell me about yourself',
#    'You are'],
#   'responses': ['I am Karabo',
#    'My name is Karabo',
#    'You can call me KB for short',
#    'I am Karabo, my friends call me KB',
#    'Karabo is my name']},
#  {'tag': 'options',
#   'patterns': ['What do you do',
#    'How can you help',
#    'What do you know',
#    'What is your purpose',
#    'How can you help'],
#   'responses': ['I can tell you about South Africa',
#    'I can give you interesting facts about South Africa']},
#  {'tag': 'south_africa_info',
#   'patterns': ['South Africa',
#    'What can you tell me about SA',
#    'SA',
#    'Tell me about SA',
#    'What about SA',
#    'What do you know about SA',
#    'Tell me more about SA',
#    'What can you tell me about South Africa',
#    'Tell me about South Africa',
#    'What about South Africa',
#    'What do you know about South Africa',
#    'Tell me more about South Africa'],
#   'responses': ['South Africa is the southern most country in Africa, it has a population of more than 59million people and covers an area of 1221 037m2. South Africa has 11 official languages. The currency used in ZAR our South African Rand which trades at about 15ZAR per 1USD.']}]

# %%
intents ={"intents":data_list}
intents
# Out:
# {'intents': [{'tag': 'class_1_1',
#    'patterns': ['How many pigs were ?', 'How many pigs were there?'],
#    'responses': ['There were three pigs.']},
#   {'tag': 'class_1_2',
#    'patterns': ['What did the big wolf say to the pigs?',
#     'What did the big wolf say to the '],
#    'responses': ['The big wolf said to the pigs that; \n he would will huff and puff and; \n blow their houses down']},
#   {'tag': 'class_1_3',
#    'patterns': ['Was the wolf good or ?', 'Was the wolf good or bad?'],
#    'responses': ['The wolf was bad.']},
#   {'tag': 'class_1_4',
#    'patterns': ['What is your house made of?', 'What is your house ?'],
#    'responses': ['My house is made of; \n bricks and cement.']},
#   {'tag': 'class_1_5',
#    'patterns': ['Who is good?', 'is that good'],
#    'responses': ['The pig is good']},
#   {'tag': 'class_1_6',
#    'patterns': ['Who is bad?', 'is bad'],
#    'responses': ['The wolf is bad.']},
#   {'tag': 'class_1_7',
#    'patterns': ['Imagine you are at home when the wolf huffs and puffs.',
#     'Imagine you are at home when the wolf huffs'],
#    'responses': ['Activity to be;\n done by yourself.']},
#   {'tag': 'class_1_8',
#    'patterns': ['Act out the story of the wolf and three pigs.',
#     'Act out the story of the wolf '],
#    'responses': ['Activity to be; \n done by yourself.']},
#   {'tag': 'class_1_9',
#    'patterns': ['Do you like to have a bath? Say why.',
#     'Do you like to have a bath? '],
#    'responses': ['Yes, I like to have a bath every;\n day to keep myself healthy, neat and tidy.']},
#   {'tag': 'class_2_0',
#    'patterns': ['Can you bathe yourself?', 'Can you bathe '],
#    'responses': ['Yes, I can bathe myself.']},
#   {'tag': 'class_2_1',
#    'patterns': ['How do you dry yourself?', 'How do you dry'],
#    'responses': ['I dry myself after a bath; \n by using a fresh towel.']},
#   {'tag': 'class_2_2',
#    'patterns': ['Have you seen an animal drying itself?',
#     'Have you seen an animal drying ?'],
#    'responses': ['Yes, I have seen my pet dog drying; \n itself by shaking off the excess water; \n from its body whenever I bathe it.']},
#   {'tag': 'class_2_3',
#    'patterns': ['Name the three friends.', 'Name the three '],
#    'responses': ['The three friends are the Bubble,; \n the Straw and the Shoe.']},
#   {'tag': 'class_2_4',
#    'patterns': ['Where did they go one day?', 'Where did they go ?'],
#    'responses': ['All the three friends went; \n to a forest one day.']},
#   {'tag': 'class_2_5',
#    'patterns': ['What did they want to do?', 'What did they want ?'],
#    'responses': ['They came to a river.; \n They wanted to cross it, but; \n did not know how to do it.']},
#   {'tag': 'class_2_6',
#    'patterns': ['How do you make bubbles?', 'How you make bubbles?'],
#    'responses': ['We can make bubbles by; \n taking some liquid soap in a container and mix it in water.; \n We can create a lather from; \n the mixture and use a straw to blow the; \n bubbles in the air.']},
#   {'tag': 'class_2_7',
#    'patterns': ['What do you wear on your feet?', 'do you wear on your feet?'],
#    'responses': ['I wear shoes, sandals, ; \n socks, etc. on my feet.']},
#   {'tag': 'class_2_8',
#    'patterns': ['How would you cross a river?', 'would you cross a river?'],
#    'responses': ['I would cross a river in a boat.']},
#   {'tag': 'class_2_9',
#    'patterns': ['How many kinds of creatures are there in the poem?',
#     'many kinds of creatures are there in the poem?'],
#    'responses': ['There are fifteen creatures; \n mentioned in the poem.']},
#   {'tag': 'class_3_0',
#    'patterns': ['are the seals happy?', 'the seals happy?'],
#    'responses': ['No, the seals are sad.']},
#   {'tag': 'class_3_1',
#    'patterns': ['Where do the fish live?', 'do the fish live?'],
#    'responses': ['The fish live in the water; \n (river, sea or ocean).']},
#   {'tag': 'class_3_2',
#    'patterns': ['What are the other things found in water?',
#     'the other things found in water?'],
#    'responses': ['The other things found in; \n water are other sea creatures, plants, oysters,; \n shells, herbs, etc.']},
#   {'tag': 'class_3_3',
#    'patterns': ['There are many creatures in the poem. Which ones have you seen?',
#     'many creatures in the poem. Which ones have you seen?'],
#    'responses': ['I have seen kitten, cats,; \n butterflies, rats, fishes, lizards,; \n bees, elephants, donkeys, etc']},
#   {'tag': 'class_3_4',
#    'patterns': ['Name the chicks in the story.', 'the chicks in the story.'],
#    'responses': ['Lalu and Peelu are the names; \n of the chicks in the story.']},
#   {'tag': 'class_3_5',
#    'patterns': ['Who liked yellow things?', 'liked yellow things?'],
#    'responses': ['Peelu liked yellow things.']},
#   {'tag': 'class_3_6',
#    'patterns': ['What did Lalu eat one day?', 'did Lalu eat one day?'],
#    'responses': ['Lalu ate a red chilli ; \n from a plant one day.']},
#   {'tag': 'class_3_7',
#    'patterns': ['What did the child see?', 'did the child see?'],
#    'responses': ['The child saw a little bird.']},
#   {'tag': 'class_3_8',
#    'patterns': ['What was the little bird doing?', 'the little bird doing?'],
#    'responses': ['The little bird sat upon a window.']},
#   {'tag': 'class_3_9',
#    'patterns': ['Do you see any birds around your school or your house?',
#     'see any birds around your school or your house?'],
#    'responses': ['Yes, I often see birds around; \n my school or my house']},
#   {'tag': 'class_4_0',
#    'patterns': ['Have you tried talking to them?',
#     'you tried talking to them?'],
#    'responses': ['Yes, I’ve tried talking to birds ; \n whenever they come and sit on my window']},
#   {'tag': 'class_4_1',
#    'patterns': ['What did Mittu see on the tree?',
#     'did Mittu see on the tree?'],
#    'responses': ['Mittu saw a big yellow; \n  mango on the tree.']},
#   {'tag': 'class_4_2',
#    'patterns': ['What did the big black crow say?',
#     'did the big black crow say?'],
#    'responses': ['The big black crow; \n told Mittu to go away.']},
#   {'tag': 'class_4_3',
#    'patterns': ['What did Mittu see under the tree?',
#     'did Mittu see under the tree?'],
#    'responses': ['Mittu saw a red balloon under the tree.']},
#   {'tag': 'class_4_4',
#    'patterns': ['Do you like eating mangoes?', 'you like eating mangoes?'],
#    'responses': ['Yes, I like eating ripe mangoes.']},
#   {'tag': 'class_4_5',
#    'patterns': ['Do you like green mangoes? Why?',
#     'you like green mangoes? Why?'],
#    'responses': ['Yes, I like green mangoes as they taste sour and; \n have a unique flavour. My grandmother prepares; \n pickles with them.']},
#   {'tag': 'class_4_6',
#    'patterns': ['Do you like yellow mangoes? Why?',
#     'you like yellow mangoes? Why?'],
#    'responses': ['Yes, I like yellow mangoes as ; \n they have a sweet flavour.']},
#   {'tag': 'class_4_7',
#    'patterns': ['How did the merry-go-round go?',
#     'did the merry-go-round go?'],
#    'responses': ['The merry-go-round went round and round']},
#   {'tag': 'class_4_8',
#    'patterns': ['How did the big brown horse go?',
#     'did the big brown horse go?'],
#    'responses': ['The big brown horse went up and down.']},
#   {'tag': 'class_4_9',
#    'patterns': ['Have you seen a merry-go-round?',
#     'you seen a merry-go-round?'],
#    'responses': ['Yes, I have seen a merry-go-round.']},
#   {'tag': 'class_5_0',
#    'patterns': ['Where have you seen it?', 'have you seen it?'],
#    'responses': ['I have seen a merry-go-round; \n in a fair and a park.']},
#   {'tag': 'class_5_1',
#    'patterns': ['Would you like to go to a fair?',
#     'you like to go to a fair?'],
#    'responses': ['Yes, I like to visit; \n a fair often.']},
#   {'tag': 'class_5_2',
#    'patterns': ['What did Grandmother and Mohini draw first?',
#     'did Grandmother and Mohini draw first?'],
#    'responses': ['Grandmother and Mohini; \n drew a circle at first.']},
#   {'tag': 'class_5_3',
#    'patterns': ['What were the colours of the balloons that Mohini drew?',
#     'were the colours of the balloons that Mohini drew?'],
#    'responses': ['Mohini drew balloons of different; \n colours such as red, blue,; \n green and yellow.']},
#   {'tag': 'class_5_4',
#    'patterns': ['Where is the apple?', 'is the apple?'],
#    'responses': ['The apple is on the tree.']},
#   {'tag': 'class_5_5',
#    'patterns': ['Where is the boy?', 'is the boy?'],
#    'responses': ['The boy is under the tree.']},
#   {'tag': 'class_5_6',
#    'patterns': ['How can the boy get the apple?', 'the boy get the apple?'],
#    'responses': ['The boy can get the apple by ; \n climbing the tree and plucking it from the tree.']},
#   {'tag': 'class_5_7',
#    'patterns': ['Do you like apples?', 'you like apples?'],
#    'responses': ['Yes, I like apples.']},
#   {'tag': 'class_5_8',
#    'patterns': ['Have you ever climbed a fruit tree?',
#     'you ever climbed a fruit tree?'],
#    'responses': ['No, I have never climbed a fruit tree']},
#   {'tag': 'class_5_9',
#    'patterns': ['Describe the picture using all the words given above.',
#     'the picture using all the words given above.'],
#    'responses': ['The tree is full of lush green leaves and; \n numerous branches.There are two birds in the picture.; \n There is also a small nest with two eggs in it.; \n A swing is tied to one of the branches.']},
#   {'tag': 'class_6_0',
#    'patterns': ['Should trees be cut?', 'the trees be cut?'],
#    'responses': ['No, Trees should not be cut.']},
#   {'tag': 'class_6_1',
#    'patterns': ['Name some trees which you have seen',
#     'some trees which you have seen'],
#    'responses': ['I have seen neem tree, mango tree, guava tree,; \n pomegranate tree, ashok tree, etc.']},
#   {'tag': 'class_6_2',
#    'patterns': ['What does the child wish to be?',
#     'does the child wish to be?'],
#    'responses': ['The child wishes to be a kite.']},
#   {'tag': 'class_6_3',
#    'patterns': ['What does the child wish to do with the breeze?',
#     'does the child wish to do with the breeze?'],
#    'responses': ['The child wishes that to ride upon the breeze ; \n and go wherever he got a chance to.']},
#   {'tag': 'class_6_4',
#    'patterns': ['What would you like to be?', 'would you like to be?'],
#    'responses': ['I would like to be a bird ; \n  and fly high in the sky.']},
#   {'tag': 'class_6_5',
#    'patterns': ['Imagine you are a bird in the sky. Describe what will you feel when you see a kite flying near you.',
#     'you are a bird in the sky. Describe what will you feel when you see a kite flying near you.'],
#    'responses': ['I will look at it and then fly a little ; \n farther so that it doesn’t harm me.']},
#   {'tag': 'class_6_6',
#    'patterns': ['What are the different things that fly in the sky?',
#     'are the different things that fly in the sky?'],
#    'responses': ['Things that fly in the sky are birds, ; \n kites, aeroplanes, helicopters, etc.']},
#   {'tag': 'class_6_7',
#    'patterns': ['If you had wings, where would you fly?',
#     'you had wings, where would you fly?'],
#    'responses': ['I would fly over mountains, rivers, etc.']},
#   {'tag': 'class_6_8',
#    'patterns': ['Who made Sundari?', 'made Sundari?'],
#    'responses': ['Bobby made Sundari.']},
#   {'tag': 'class_6_9',
#    'patterns': ['Why did Bobby call his kite ‘Sundari’?',
#     'did Bobby call his kite ‘Sundari’?'],
#    'responses': ['Bobby called his kite ‘Sundari’; \n  because it was beautiful.']},
#   {'tag': 'class_7_0',
#    'patterns': ['Did Sundari fly very high at first?',
#     'Sundari fly very high at first?'],
#    'responses': ['No, Sundari did not fly very high at first.']},
#   {'tag': 'class_7_1',
#    'patterns': ['What made Sundari really happy?',
#     'made Sundari really happy?'],
#    'responses': ['Sundari became really happy when ; \n Bobby let her go and fly high in the sky.']},
#   {'tag': 'class_7_2',
#    'patterns': ['Do you like to fly kites?', 'you like to fly kites?'],
#    'responses': ['Yes, I like to fly kites.']},
#   {'tag': 'class_7_3',
#    'patterns': ['Who helps you to fly kites', 'helps you to fly kites'],
#    'responses': ['My brother helps me to fly kites']},
#   {'tag': 'class_7_4',
#    'patterns': ['Name the objects in your own language.',
#     'the objects in your own language.'],
#    'responses': ['The student has to do as directed.']},
#   {'tag': 'class_7_5',
#    'patterns': ['Now say the story in English using the words rain, wind, crow, nest, is, has, blows, flies.',
#     'the story in English using the words rain, wind, crow, nest, is, has, blows, flies.'],
#    'responses': ['The student has to do as directed.']},
#   {'tag': 'class_7_6',
#    'patterns': ['How does a turtle walk?', 'does a turtle walk?'],
#    'responses': ['The turtle walks very slowly.']},
#   {'tag': 'class_7_7',
#    'patterns': ['What does the turtle carry on its back?',
#     'does the turtle carry on its back?'],
#    'responses': ['The turtle carries its home on its back.']},
#   {'tag': 'class_7_8',
#    'patterns': ['Where does the turtle go when it is tired?',
#     'does the turtle go when it is tired?'],
#    'responses': ['The turtle goes back to its shell when it is tired.']},
#   {'tag': 'class_7_9',
#    'patterns': ['What is the turtle’s house called?',
#     'is the turtle’s house called?'],
#    'responses': ['The turtle’s house is called a shell.']},
#   {'tag': 'class_8_0',
#    'patterns': ['What other reasons can you give for a turtle going into its house?',
#     'can you give for a turtle going into its house?'],
#    'responses': ['There can be multiple reasons for a turtle ; \n going into its house- to save itself from strong winds or storms, ; \n to hide from enemies or other dangers, etc.']},
#   {'tag': 'class_8_1',
#    'patterns': ['Imagine you are a turtle. Crawl like a turtle.',
#     'you are a turtle. Crawl like a turtle.'],
#    'responses': ['The student has to do as directed in the question.']},
#   {'tag': 'class_8_2',
#    'patterns': ['Now you are tired so get into your shell and go to sleep.',
#     'you are tired so get into your shell and go to sleep.'],
#    'responses': ['The student has to do as directed in the question.']},
#   {'tag': 'class_8_3',
#    'patterns': ['Wake up and start to crawl again.',
#     'when Wake up and start to crawl again.'],
#    'responses': ['The student has to do as directed in the question.']},
#   {'tag': 'class_8_4',
#    'patterns': ['Now hide in your shell because some naughty children are near you',
#     'your shell because some naughty children are near you'],
#    'responses': ['The student has to do as directed in the question.']},
#   {'tag': 'class_8_5',
#    'patterns': ['What was the tiger doing when the mosquito came buzzing by?',
#     'the tiger doing when the mosquito came buzzing by?'],
#    'responses': ['The tiger was dozing under a tree when the mosquito came buzzing by.']},
#   {'tag': 'class_8_6',
#    'patterns': ['Why did the tiger’s cheek start to bleed?',
#     'the tiger’s cheek start to bleed?'],
#    'responses': ['The tiger’s cheek started to bleed because ; \n while trying to hit the mosquito,; \n the tiger hit himself with his paw.']},
#   {'tag': 'class_8_7',
#    'patterns': ['Why did the tiger walk away?', 'the tiger walk away?'],
#    'responses': ['The tiger walked away because he was helpless ; \n and could not make the mosquito fly away from him.']},
#   {'tag': 'class_8_8',
#    'patterns': ['Why did the mosquito say, “I am not afraid of you!”?'],
#    'responses': ['The mosquito said so because the tiger was ; \n behaving as if everyone should be afraid of him.']},
#   {'tag': 'class_1_poems',
#    'patterns': ['A Happy Child'],
#    'responses': ['My house is red - a little house;\nA happy child am I.\nI laugh and play the whole day long,\nI hardly ever cry.\nI have a tree, a green, green tree,\nTo shade me from the sun;\nAnd under it I often sit,\nWhen all my play is done.']},
#   {'tag': 'class_1_poems1',
#    'patterns': ['After a Bath',
#     'After a Bath Poem',
#     'what is After a Bath poem',
#     'Hey teach me After a Bath poem',
#     'teach me After a Bath poem'],
#    'responses': ['After my bath\nI try, try, try\nto wipe myself\ntill I’m dry, dry, dry.\nHands to wipe\nand fingers and toes\nand two wet legs\nand a shiny nose.\nJust think how much\nless time I’d take\nif I were a dog\nand could shake, shake, shake.\n']},
#   {'tag': 'class_1_poems2',
#    'patterns': ['One little kitten',
#     'One little kitten Poem',
#     'One little kitten Rythm'],
#    'responses': ['Two big cats\nThree baby butterflies\nFour big rats\nFive fat fishes\nSix sad seals\nSeven silly seagulls\nEight happy eels;\nNine nervous lizards\nTen brave bees\nEleven smelly elephants\nTwelve fat fleas\nThirteen alligators\nFourteen whales\nFifteen donkeys\nWith fifteen tails.']},
#   {'tag': 'class_1_poems3',
#    'patterns': ['Once I saw a Little Bird',
#     'Once I saw a Little Bird Poem',
#     'Once I saw a Little Bird Rythm'],
#    'responses': ['Once I saw a little bird\nCome hop, hop, hop,\nI cried, “Little bird,\nWill you stop, stop, stop?”\nI was going to the window\nTo say, “How do you do?”\nBut he shook his little tail\nAnd away he flew.']},
#   {'tag': 'class_1_poems4',
#    'patterns': ['Merry Go Round',
#     'Merry Go Round Poem',
#     'Merry Go Round Rythm'],
#    'responses': ['I climbed up on the merry-go-round,\nAnd it went round and round.\nI climbed up on a big brown horse,\nAnd it went up and down.Around and round\nAnd up and down,\nAround and round\nAnd up and down.\nI sat high up\nOn a big brown horse\nAnd rode around\nOn the merry-go-round\nAnd rode around\nOn the merry-go-round\nI rode around\nOn the merry-go-round\nAround\nAnd round\nAnd']},
#   {'tag': 'class_1_poems5',
#    'patterns': ['If I Were an Apple',
#     'If I Were an Apple Poem',
#     'If I Were an Apple Rythm'],
#    'responses': ['If I were an apple\nAnd grew on a tree,\nI think I’d drop down\nOn a nice boy like me.\nI wouldn’t stay there\nGiving nobody joy,\nI’d fall down at once\nAnd say, “Eat me, my boy!']},
#   {'tag': 'greeting',
#    'patterns': ['Hi there',
#     'How are you',
#     'Is anyone there?',
#     'Hey',
#     'Hola',
#     'Hello',
#     'Good day',
#     'Hey',
#     'Ekse',
#     'Hi'],
#    'responses': ['Hi stranger',
#     'Yebo yes, how can I help',
#     'Ey watsupp',
#     'Ekse Hoezit',
#     'Hola',
#     'Hey dude',
#     'You again']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye', 'See you later', 'Goodbye', 'Ok bye', 'Bye Bye'],
#    'responses': ['See you!',
#     'Have a nice day',
#     'Sure Bye',
#     'Later dude',
#     'Sayoonara',
#     'Peace out',
#     'Sure dude',
#     'Ciao']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!',
#     'Any time!',
#     'My pleasure',
#     'You are welcome',
#     'Sure dude']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand',
#     'I am still here dude']},
#   {'tag': 'name',
#    'patterns': ['What is your name',
#     'Whats your name',
#     'Tell me your name',
#     'Who are you',
#     'Ungubani',
#     'Tell me about yourself',
#     'You are'],
#    'responses': ['I am Karabo',
#     'My name is Karabo',
#     'You can call me KB for short',
#     'I am Karabo, my friends call me KB',
#     'Karabo is my name']},
#   {'tag': 'options',
#    'patterns': ['What do you do',
#     'How can you help',
#     'What do you know',
#     'What is your purpose',
#     'How can you help'],
#    'responses': ['I can tell you about South Africa',
#     'I can give you interesting facts about South Africa']},
#   {'tag': 'south_africa_info',
#    'patterns': ['South Africa',
#     'What can you tell me about SA',
#     'SA',
#     'Tell me about SA',
#     'What about SA',
#     'What do you know about SA',
#     'Tell me more about SA',
#     'What can you tell me about South Africa',
#     'Tell me about South Africa',
#     'What about South Africa',
#     'What do you know about South Africa',
#     'Tell me more about South Africa'],
#    'responses': ['South Africa is the southern most country in Africa, it has a population of more than 59million people and covers an area of 1221 037m2. South Africa has 11 official languages. The currency used in ZAR our South African Rand which trades at about 15ZAR per 1USD.']}]}

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        w = nltk.word_tokenize(pattern)
        words.extend(w)

        documents.append((w, intent['tag']))


        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)
# Out:
# 217 documents
# 90 classes ['class_1_1', 'class_1_2', 'class_1_3', 'class_1_4', 'class_1_5', 'class_1_6', 'class_1_7', 'class_1_8', 'class_1_9', 'class_1_poems', 'class_1_poems1', 'class_1_poems2', 'class_1_poems3', 'class_1_poems4', 'class_1_poems5', 'class_2_0', 'class_2_1', 'class_2_2', 'class_2_3', 'class_2_4', 'class_2_5', 'class_2_6', 'class_2_7', 'class_2_8', 'class_2_9', 'class_3_0', 'class_3_1', 'class_3_2', 'class_3_3', 'class_3_4', 'class_3_5', 'class_3_6', 'class_3_7', 'class_3_8', 'class_3_9', 'class_4_0', 'class_4_1', 'class_4_2', 'class_4_3', 'class_4_4', 'class_4_5', 'class_4_6', 'class_4_7', 'class_4_8', 'class_4_9', 'class_5_0', 'class_5_1', 'class_5_2', 'class_5_3', 'class_5_4', 'class_5_5', 'class_5_6', 'class_5_7', 'class_5_8', 'class_5_9', 'class_6_0', 'class_6_1', 'class_6_2', 'class_6_3', 'class_6_4', 'class_6_5', 'class_6_6', 'class_6_7', 'class_6_8', 'class_6_9', 'class_7_0', 'class_7_1', 'class_7_2', 'class_7_3', 'class_7_4', 'class_7_5', 'class_7_6', 'class_7_7', 'class_7_8', 'class_7_9', 'class_8_0', 'class_8_1', 'class_8_2', 'class_8_3', 'class_8_4', 'class_8_5', 'class_8_6', 'class_8_7', 'class_8_8', 'goodbye', 'greeting', 'name', 'options', 'south_africa_info', 'thanks']
# 242 unique lemmatized words ["'s", ',', '.', 'a', 'about', 'above', 'act', 'afraid', 'africa', 'after', 'again', 'all', 'am', 'an', 'and', 'animal', 'any', 'anyone', 'apple', 'are', 'around', 'at', 'away', 'awesome', 'back', 'bad', 'balloon', 'bath', 'bathe', 'be', 'because', 'big', 'bird', 'black', 'bleed', 'blow', 'bobby', 'boy', 'breeze', 'brown', 'bubble', 'buzzing', 'by', 'bye', 'call', 'called', 'came', 'can', 'carry', 'cheek', 'chick', 'child', 'climbed', 'colour', 'crawl', 'creature', 'cross', 'crow', 'cut', 'day', 'describe', 'did', 'different', 'do', 'doe', 'doing', 'draw', 'drew', 'dry', 'drying', 'eat', 'eating', 'ekse', 'english', 'ever', 'fair', 'feel', 'first', 'fish', 'fly', 'flying', 'foot', 'for', 'found', 'friend', 'fruit', 'get', 'give', 'given', 'go', 'going', 'good', 'goodbye', 'grandmother', 'green', 'ha', 'had', 'happy', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hide', 'high', 'his', 'hola', 'home', 'horse', 'house', 'how', 'huff', 'i', 'if', 'imagine', 'in', 'into', 'is', 'it', 'itself', 'kind', 'kite', 'kitten', 'know', 'lalu', 'language', 'later', 'like', 'liked', 'little', 'live', 'made', 'make', 'mango', 'many', 'me', 'merry', 'merry-go-round', 'mittu', 'mohini', 'more', 'mosquito', 'name', 'naughty', 'near', 'nest', 'not', 'now', 'object', 'of', 'ok', 'on', 'once', 'one', 'or', 'other', 'out', 'own', 'picture', 'pig', 'poem', 'puff', 'purpose', 'rain', 'really', 'reason', 'river', 'round', 'rythm', 's', 'sa', 'saw', 'say', 'school', 'seal', 'see', 'seen', 'shell', 'should', 'sky', 'sleep', 'so', 'some', 'south', 'start', 'story', 'sundari', 'talking', 'teach', 'tell', 'thank', 'thanks', 'that', 'the', 'them', 'there', 'they', 'thing', 'three', 'tiger', 'tired', 'to', 'tree', 'tried', 'turtle', 'under', 'ungubani', 'up', 'using', 'very', 'wa', 'wake', 'walk', 'want', 'water', 'wear', 'were', 'what', 'whats', 'when', 'where', 'which', 'who', 'why', 'will', 'wind', 'wing', 'wish', 'with', 'wolf', 'word', 'would', 'yellow', 'you', 'your', 'yourself', '‘', '’', '“', '”']

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents
400
# 44/44 [==============================] - 1s 13ms/step - loss: 1.2601 - accuracy: 0.6728
# Epoch 171/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.3905 - accuracy: 0.6866
# Epoch 172/400
# 44/44 [==============================] - 1s 18ms/step - loss: 1.2772 - accuracy: 0.6498
# Epoch 173/400
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1919 - accuracy: 0.6959
# Epoch 174/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.3522 - accuracy: 0.6359
# Epoch 175/400
# 44/44 [==============================] - 1s 12ms/step - loss: 1.2982 - accuracy: 0.6313
# Epoch 176/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.2250 - accuracy: 0.6866
# Epoch 177/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.2077 - accuracy: 0.6498
# Epoch 178/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.2757 - accuracy: 0.6406
# Epoch 179/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.2211 - accuracy: 0.6544
# Epoch 180/400
# 44/44 [==============================] - 1s 13ms/step - loss: 1.2193 - accuracy: 0.6682
# Epoch 181/400
# 44/44 [==============================] - 1s 12ms/step - loss: 1.0833 - accuracy: 0.7327
# Epoch 182/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.1755 - accuracy: 0.7281
# Epoch 183/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.2007 - accuracy: 0.6452
# Epoch 184/400
# 44/44 [==============================] - 1s 16ms/step - loss: 1.0896 - accuracy: 0.7097
# Epoch 185/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.1462 - accuracy: 0.6912
# Epoch 186/400
# 44/44 [==============================] - 0s 11ms/step - loss: 1.1666 - accuracy: 0.7051
# Epoch 187/400
# 44/44 [==============================] - 1s 13ms/step - loss: 1.1556 - accuracy: 0.6820
# Epoch 188/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.1117 - accuracy: 0.7005
# Epoch 189/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.1873 - accuracy: 0.6959
# Epoch 190/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.0812 - accuracy: 0.6774
# Epoch 191/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0894 - accuracy: 0.7373
# Epoch 192/400
# 44/44 [==============================] - 1s 12ms/step - loss: 1.2222 - accuracy: 0.7005
# Epoch 193/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.1289 - accuracy: 0.6959
# Epoch 194/400
# 44/44 [==============================] - 1s 16ms/step - loss: 1.2237 - accuracy: 0.6359
# Epoch 195/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0930 - accuracy: 0.7189
# Epoch 196/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.1209 - accuracy: 0.7051
# Epoch 197/400
# 44/44 [==============================] - 1s 13ms/step - loss: 1.0117 - accuracy: 0.7373
# Epoch 198/400
# 44/44 [==============================] - 1s 12ms/step - loss: 1.0491 - accuracy: 0.7005
# Epoch 199/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0540 - accuracy: 0.7051
# Epoch 200/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0050 - accuracy: 0.7327
# Epoch 201/400
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0446 - accuracy: 0.7465
# Epoch 202/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9889 - accuracy: 0.7189
# Epoch 203/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.8825 - accuracy: 0.7650
# Epoch 204/400
# 44/44 [==============================] - 1s 12ms/step - loss: 1.0439 - accuracy: 0.7143
# Epoch 205/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.9666 - accuracy: 0.7327
# Epoch 206/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0274 - accuracy: 0.7465
# Epoch 207/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0407 - accuracy: 0.7327
# Epoch 208/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0695 - accuracy: 0.6774
# Epoch 209/400
# 44/44 [==============================] - 1s 13ms/step - loss: 1.0279 - accuracy: 0.7143
# Epoch 210/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.9404 - accuracy: 0.7373
# Epoch 211/400
# 44/44 [==============================] - 1s 14ms/step - loss: 1.0421 - accuracy: 0.7143
# Epoch 212/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.9691 - accuracy: 0.7235
# Epoch 213/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.9668 - accuracy: 0.7235
# Epoch 214/400
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0196 - accuracy: 0.7235
# Epoch 215/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.9384 - accuracy: 0.7373
# Epoch 216/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.9446 - accuracy: 0.7005
# Epoch 217/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.8474 - accuracy: 0.7926
# Epoch 218/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.9793 - accuracy: 0.7558
# Epoch 219/400
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0115 - accuracy: 0.7327
# Epoch 220/400
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9649 - accuracy: 0.7419
# Epoch 221/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.9265 - accuracy: 0.7604
# Epoch 222/400
# 44/44 [==============================] - 1s 12ms/step - loss: 1.0535 - accuracy: 0.7005
# Epoch 223/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.8484 - accuracy: 0.7696
# Epoch 224/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.8548 - accuracy: 0.8018
# Epoch 225/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.9578 - accuracy: 0.7281
# Epoch 226/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.7293 - accuracy: 0.8203
# Epoch 227/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.9140 - accuracy: 0.7419
# Epoch 228/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.9104 - accuracy: 0.7465
# Epoch 229/400
# 44/44 [==============================] - 1s 15ms/step - loss: 1.0122 - accuracy: 0.7327
# Epoch 230/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.9507 - accuracy: 0.7327
# Epoch 231/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.9333 - accuracy: 0.7465
# Epoch 232/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.8205 - accuracy: 0.7650
# Epoch 233/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.7457 - accuracy: 0.7972
# Epoch 234/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.9038 - accuracy: 0.7373
# Epoch 235/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.8027 - accuracy: 0.7880
# Epoch 236/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8778 - accuracy: 0.7419
# Epoch 237/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8780 - accuracy: 0.7327
# Epoch 238/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8579 - accuracy: 0.7512
# Epoch 239/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.8428 - accuracy: 0.7465
# Epoch 240/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.8399 - accuracy: 0.7465
# Epoch 241/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.8738 - accuracy: 0.7788
# Epoch 242/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.7852 - accuracy: 0.8111
# Epoch 243/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.9690 - accuracy: 0.7051
# Epoch 244/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.7174 - accuracy: 0.8157
# Epoch 245/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.9048 - accuracy: 0.7465
# Epoch 246/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8334 - accuracy: 0.7788
# Epoch 247/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8858 - accuracy: 0.7419
# Epoch 248/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7979 - accuracy: 0.7834
# Epoch 249/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7442 - accuracy: 0.7742
# Epoch 250/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.7997 - accuracy: 0.7650
# Epoch 251/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.7638 - accuracy: 0.7926
# Epoch 252/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8684 - accuracy: 0.7465
# Epoch 253/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.8049 - accuracy: 0.7696
# Epoch 254/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8415 - accuracy: 0.7512
# Epoch 255/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8539 - accuracy: 0.7742
# Epoch 256/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.7821 - accuracy: 0.7880
# Epoch 257/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.6974 - accuracy: 0.8065
# Epoch 258/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8022 - accuracy: 0.7788
# Epoch 259/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7085 - accuracy: 0.8018
# Epoch 260/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7284 - accuracy: 0.7972
# Epoch 261/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7053 - accuracy: 0.8295
# Epoch 262/400
# 44/44 [==============================] - 1s 11ms/step - loss: 0.7750 - accuracy: 0.7788
# Epoch 263/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.8097 - accuracy: 0.7742
# Epoch 264/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7331 - accuracy: 0.8157
# Epoch 265/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7662 - accuracy: 0.7696
# Epoch 266/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7610 - accuracy: 0.7880
# Epoch 267/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.8326 - accuracy: 0.7558
# Epoch 268/400
# 44/44 [==============================] - 1s 11ms/step - loss: 0.7340 - accuracy: 0.7972
# Epoch 269/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.8855 - accuracy: 0.7327
# Epoch 270/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7271 - accuracy: 0.8203
# Epoch 271/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8008 - accuracy: 0.7742
# Epoch 272/400
# 44/44 [==============================] - 1s 20ms/step - loss: 0.6913 - accuracy: 0.8018
# Epoch 273/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.8346 - accuracy: 0.7327
# Epoch 274/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.7668 - accuracy: 0.7834
# Epoch 275/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.7565 - accuracy: 0.8387
# Epoch 276/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7312 - accuracy: 0.8157
# Epoch 277/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7840 - accuracy: 0.7419
# Epoch 278/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7570 - accuracy: 0.7650
# Epoch 279/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.6466 - accuracy: 0.8018
# Epoch 280/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.7044 - accuracy: 0.8157
# Epoch 281/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.6437 - accuracy: 0.8525
# Epoch 282/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.7590 - accuracy: 0.7742
# Epoch 283/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7969 - accuracy: 0.7650
# Epoch 284/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.7324 - accuracy: 0.7880
# Epoch 285/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.
400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.6035 - accuracy: 0.8249
# Epoch 347/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.5250 - accuracy: 0.8802
# Epoch 348/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.6180 - accuracy: 0.8157
# Epoch 349/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.5222 - accuracy: 0.8341
# Epoch 350/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4612 - accuracy: 0.9032
# Epoch 351/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.5925 - accuracy: 0.8249
# Epoch 352/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.5706 - accuracy: 0.8295
# Epoch 353/400
# 44/44 [==============================] - 1s 18ms/step - loss: 0.5655 - accuracy: 0.8341
# Epoch 354/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.5169 - accuracy: 0.8387
# Epoch 355/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.5482 - accuracy: 0.8479
# Epoch 356/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.5534 - accuracy: 0.8341
# Epoch 357/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.5161 - accuracy: 0.8710
# Epoch 358/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.4855 - accuracy: 0.8848
# Epoch 359/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.6148 - accuracy: 0.8065
# Epoch 360/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.5329 - accuracy: 0.8249
# Epoch 361/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.5839 - accuracy: 0.8157
# Epoch 362/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4719 - accuracy: 0.8940
# Epoch 363/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4824 - accuracy: 0.8664
# Epoch 364/400
# 44/44 [==============================] - 1s 18ms/step - loss: 0.4931 - accuracy: 0.8802
# Epoch 365/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4615 - accuracy: 0.8479
# Epoch 366/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.5844 - accuracy: 0.8295
# Epoch 367/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.5901 - accuracy: 0.8341
# Epoch 368/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.5441 - accuracy: 0.8710
# Epoch 369/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.4707 - accuracy: 0.8802
# Epoch 370/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.5686 - accuracy: 0.8249
# Epoch 371/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.5497 - accuracy: 0.8387
# Epoch 372/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.5560 - accuracy: 0.8479
# Epoch 373/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.6143 - accuracy: 0.7926
# Epoch 374/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.5638 - accuracy: 0.8341
# Epoch 375/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4276 - accuracy: 0.9171
# Epoch 376/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.6232 - accuracy: 0.8479
# Epoch 377/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.5479 - accuracy: 0.8525
# Epoch 378/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.4160 - accuracy: 0.8986
# Epoch 379/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.5325 - accuracy: 0.8571
# Epoch 380/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4299 - accuracy: 0.8986
# Epoch 381/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.4783 - accuracy: 0.8848
# Epoch 382/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.4298 - accuracy: 0.8848
# Epoch 383/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.5815 - accuracy: 0.8203
# Epoch 384/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.4817 - accuracy: 0.8756
# Epoch 385/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.5706 - accuracy: 0.8249
# Epoch 386/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.5223 - accuracy: 0.8525
# Epoch 387/400
# 44/44 [==============================] - 1s 16ms/step - loss: 0.5142 - accuracy: 0.8479
# Epoch 388/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.5171 - accuracy: 0.8525
# Epoch 389/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.4906 - accuracy: 0.8295
# Epoch 390/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.4290 - accuracy: 0.8710
# Epoch 391/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4360 - accuracy: 0.9032
# Epoch 392/400
# 44/44 [==============================] - 1s 14ms/step - loss: 0.5446 - accuracy: 0.8710
# Epoch 393/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.4779 - accuracy: 0.8571
# Epoch 394/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.4905 - accuracy: 0.8802
# Epoch 395/400
# 44/44 [==============================] - 1s 12ms/step - loss: 0.4277 - accuracy: 0.8710
# Epoch 396/400
# 44/44 [==============================] - 1s 13ms/step - loss: 0.5567 - accuracy: 0.8387
# Epoch 397/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.4611 - accuracy: 0.8848
# Epoch 398/400
# 44/44 [==============================] - 1s 17ms/step - loss: 0.4707 - accuracy: 0.8756
# Epoch 399/400
# 44/44 [==============================] - 1s 21ms/step - loss: 0.4133 - accuracy: 0.8802
# Epoch 400/400
# 44/44 [==============================] - 1s 15ms/step - loss: 0.4986 - accuracy: 0.8433
# model created
